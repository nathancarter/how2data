# %% [markdown]
# ---
# author: Nathan Carter (ncarter@bentley.edu)
# ---
#
# The R programming language comes with many free datasets built in.  To make these
# same datasets available to Python programmers as well, you can install and import
# the `rdatasets` package.
#
# First, ensure that you have it installed, by running `pip install rdatasets` or
# `conda install rdatasets` from your command line.  Then you can get access to many
# datasets as follows:

# %%
from rdatasets import data
df = data( 'iris' )  # Load the famous Fisher's irises dataset
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# But what datasets are available?  There are many!  You can find a full list in the package itself.

# %%
from rdatasets import summary
summary()
# Out:
#      Package        Item                                              Title  \
# 0       boot        acme                             Monthly Excess Returns
# 1       boot        aids       Delay in AIDS Reporting in England and Wales
# 2       boot   aircondit             Failures of Air-conditioning Equipment
# 3       boot  aircondit7             Failures of Air-conditioning Equipment
# 4       boot        amis                     Car Speeding and Warning Signs
# ...      ...         ...                                                ...
# 1340   Zelig       tobin                                 Tobin's Tobit Data
# 1341   Zelig     turnout  Turnout Data Set from the National Election Su...
# 1342   Zelig  voteincome  Sample Turnout and Demographic Data from the 2...
# 1343   Zelig      Weimar                          1932 Weimar election data
# 1344   Zelig   Zelig.url                           Table of links for Zelig
#
#       Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0       60     3         0            1         0          0          2
# 1      570     6         1            0         0          0          6
# 2       12     1         0            0         0          0          1
# 3       24     1         0            0         0          0          1
# 4     8437     4         1            0         0          0          4
# ...    ...   ...       ...          ...       ...        ...        ...
# 1340    20     3         0            0         0          0          3
# 1341  2000     5         2            0         1          0          4
# 1342  1500     7         3            0         1          0          6
# 1343    10    11         0            0         0          0         11
# 1344    49     2         0            0         2          0          0
#
#                                                     CSV  \
# 0     https://raw.github.com/vincentarelbundock/Rdat...
# 1     https://raw.github.com/vincentarelbundock/Rdat...
# 2     https://raw.github.com/vincentarelbundock/Rdat...
# 3     https://raw.github.com/vincentarelbundock/Rdat...
# 4     https://raw.github.com/vincentarelbundock/Rdat...
# ...                                                 ...
# 1340  https://raw.github.com/vincentarelbundock/Rdat...
# 1341  https://raw.github.com/vincentarelbundock/Rdat...
# 1342  https://raw.github.com/vincentarelbundock/Rdat...
# 1343  https://raw.github.com/vincentarelbundock/Rdat...
# 1344  https://raw.github.com/vincentarelbundock/Rdat...
#
#                                                     Doc
# 0     https://raw.github.com/vincentarelbundock/Rdat...
# 1     https://raw.github.com/vincentarelbundock/Rdat...
# 2     https://raw.github.com/vincentarelbundock/Rdat...
# 3     https://raw.github.com/vincentarelbundock/Rdat...
# 4     https://raw.github.com/vincentarelbundock/Rdat...
# ...                                                 ...
# 1340  https://raw.github.com/vincentarelbundock/Rdat...
# 1341  https://raw.github.com/vincentarelbundock/Rdat...
# 1342  https://raw.github.com/vincentarelbundock/Rdat...
# 1343  https://raw.github.com/vincentarelbundock/Rdat...
# 1344  https://raw.github.com/vincentarelbundock/Rdat...
#
# [1345 rows x 12 columns]
